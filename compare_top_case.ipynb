# %%
import xarray as xr
import proplot as pplt
import pandas as pd
import numpy as np
from pathlib import Path

from AOSCMcoupling.files import OIFSPreprocessor, NEMOPreprocessor

# %%
start_date = pd.Timestamp("2020-04-16")
oifs_preprocessor = OIFSPreprocessor(
    start_date, np.timedelta64(-1, "h")
)
nemo_preprocessor = NEMOPreprocessor(
    start_date, np.timedelta64(-1, "h")
)

# %%
plotting_output_dir = Path("plots/TOP")
plotting_output_dir.mkdir(exist_ok=True)

# %%
ece4_dir = Path("output")
ece3_dir = Path("PAPA")

# %%
exp_ids = ["TOP0", "TOP1", "TOP2", "TOPS_30"]
oifs_progvar_ece3 = [
    xr.open_mfdataset(
        f"{ece3_dir}/{exp_id}/progvar.nc", preprocess=oifs_preprocessor.preprocess
    )
    for exp_id in exp_ids
]
oifs_diagvar_ece3 = [
    xr.open_mfdataset(
        f"{ece3_dir}/{exp_id}/diagvar.nc", preprocess=oifs_preprocessor.preprocess
    )
    for exp_id in exp_ids
]
nemo_t_grids_ece3 = [
    xr.open_mfdataset(
        f"{ece3_dir}/{exp_id}/*_T.nc", preprocess=nemo_preprocessor.preprocess
    )
    for exp_id in exp_ids
]
nemo_u_grids_ece3 = [
    xr.open_mfdataset(
        f"{ece3_dir}/{exp_id}/*_U.nc", preprocess=nemo_preprocessor.preprocess
    )
    for exp_id in exp_ids
]
nemo_v_grids_ece3 = [
    xr.open_mfdataset(
        f"{ece3_dir}/{exp_id}/*_V.nc", preprocess=nemo_preprocessor.preprocess
    )
    for exp_id in exp_ids
]

oifs_progvar_ece4 = [
    xr.open_mfdataset(
        f"{ece4_dir}/{exp_id}/progvar.nc", preprocess=oifs_preprocessor.preprocess
    )
    for exp_id in exp_ids
]
oifs_diagvar_ece4 = [
    xr.open_mfdataset(
        f"{ece4_dir}/{exp_id}/diagvar.nc", preprocess=oifs_preprocessor.preprocess
    )
    for exp_id in exp_ids
]
nemo_t_grids_ece4 = [
    xr.open_mfdataset(
        f"{ece4_dir}/{exp_id}/*_T*.nc", preprocess=nemo_preprocessor.preprocess
    )
    for exp_id in exp_ids
]
nemo_u_grids_ece4 = [
    xr.open_mfdataset(
        f"{ece4_dir}/{exp_id}/*_U*.nc", preprocess=nemo_preprocessor.preprocess
    )
    for exp_id in exp_ids
]
nemo_v_grids_ece4 = [
    xr.open_mfdataset(
        f"{ece4_dir}/{exp_id}/*_V*.nc", preprocess=nemo_preprocessor.preprocess
    )
    for exp_id in exp_ids
]

# %% [markdown]
# ## Boundary Layer Height

# %%
colors = ["m", "c", "y", "k"]
labels = ["parallel", "atm-first", "oce-first", "converged SWR"]
alpha = 1
linestyles = ["--", ":", "-.", "-"]

fig, ax = pplt.subplots(width="70em", height="40em")

for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece3[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    ax.plot(
        oifs_diagvar.pbl_height,
        color=color,
        label=label,
        alpha=alpha,
        ls=linestyle,
    )
ax.format(
    ylabel=r"Boundary Layer Height $[m]$",
    xlabel="Time",
    title="Boundary Layer Height (Control Experiment, ECE3)",
    xrotation=30,
)
ax.legend(ncols=1)
fig.savefig(plotting_output_dir / "ece3_pbl_height.pdf")
# Out:
# Figure(nrows=1, ncols=1, figwidth=8.75, figheight=5.0)

# %%
colors = ["m", "c", "y", "k"]
labels = ["parallel", "atm-first", "oce-first", "converged SWR"]
alpha = 1
linestyles = ["--", ":", "-.", "-"]

fig, ax = pplt.subplots(width="70em", height="40em")

for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece4[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    ax.plot(
        oifs_diagvar.pbl_height,
        color=color,
        label=label,
        alpha=alpha,
        ls=linestyle,
    )
ax.format(
    ylabel=r"Boundary Layer Height $[m]$",
    xlabel="Time",
    title="Boundary Layer Height (Control Experiment, ECE4)",
    xrotation=30,
)
ax.legend(ncols=1)
fig.savefig(plotting_output_dir / "ece4_pbl_height.pdf")
# Out:
# Figure(nrows=1, ncols=1, figwidth=8.75, figheight=5.0)

# %% [markdown]
# ## Boundary Layer Type

# %%
fig, ax = pplt.subplots(width="70em", height="30em")

colors = ["m", "c", "y", "k"]
labels = ["parallel", "atmosphere-first", "ocean-first", "converged SWR"]
shifts = [-0.12, -0.04, 0.04, 0.12]
for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece3[i]
    color = colors[i]
    label = labels[i]
    shift = shifts[i]
    ax.scatter(
        oifs_diagvar.pbl_type + shift,
        color=color,
        label=label,
        marker=".",
    )
ax.format(
    title="Boundary Layer Type (Control Experiment, ECE3)",
    ylabel="Boundary Layer Type",
    yticks=[0, 1, 2, 3],
    yticklabels=["DS", "DC", "Sc", "Cu"],
    ytickminor=False,
    xrotation=30,
    xlabel="Time",
)
ax.legend(ncol=1)

fig.savefig(plotting_output_dir / "ece3_pbl_types.pdf")
# Out:
# Figure(nrows=1, ncols=1, figwidth=8.75, figheight=3.75)

# %%
fig, ax = pplt.subplots(width="70em", height="30em")

colors = ["m", "c", "y", "k"]
labels = ["parallel", "atmosphere-first", "ocean-first", "converged SWR"]
shifts = [-0.12, -0.04, 0.04, 0.12]
for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece4[i]
    color = colors[i]
    label = labels[i]
    shift = shifts[i]
    ax.scatter(
        oifs_diagvar.pbl_type + shift,
        color=color,
        label=label,
        marker=".",
    )
ax.format(
    title="Boundary Layer Type (Control Experiment, ECE4)",
    ylabel="Boundary Layer Type",
    yticks=[0, 1, 2, 3],
    yticklabels=["DS", "DC", "Sc", "Cu"],
    ytickminor=False,
    xrotation=30,
    xlabel="Time",
)
ax.legend(ncol=1)

fig.savefig(plotting_output_dir / "ece4_pbl_types.pdf")
# Out:
# Figure(nrows=1, ncols=1, figwidth=8.75, figheight=3.75)

# %%
colors = ["m", "c", "y", "k"]
labels = ["parallel", "atm-first", "oce-first", "converged SWR"]
alpha = 1
linestyles = ["--", ":", "-.", "-"]

fig, ax = pplt.subplots(width="70em", height="40em")

for i in range(len(colors)):
    nemo_t_grid = nemo_t_grids_ece3[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    ax.plot(
        nemo_t_grid.somxl010,
        color=color,
        label=label,
        alpha=alpha,
        ls=linestyle,
    )

ax.format(
    ylabel="Mixed Layer Depth [m]",
    xlabel="Time",
    title="Mixed Layer Depth (Control Experiment, ECE3)",
    xrotation=30,
)

ax.legend(ncols=1)
fig.savefig(plotting_output_dir / "ece3_mldepth.pdf")
# Out:
# Figure(nrows=1, ncols=1, figwidth=8.75, figheight=5.0)

# %%
colors = ["m", "c", "y", "k"]
labels = ["parallel", "atm-first", "oce-first", "converged SWR"]
alpha = 1
linestyles = ["--", ":", "-.", "-"]

fig, ax = pplt.subplots(width="70em", height="40em")

for i in range(len(colors)):
    nemo_t_grid = nemo_t_grids_ece4[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    ax.plot(
        nemo_t_grid.somxl010,
        color=color,
        label=label,
        alpha=alpha,
        ls=linestyle,
    )

ax.format(
    ylabel="Mixed Layer Depth [m]",
    xlabel="Time",
    title="Mixed Layer Depth (Control Experiment, ECE4)",
    xrotation=30,
)

ax.legend(ncols=1)
fig.savefig(plotting_output_dir / "ece4_mldepth.pdf")
# Out:
# Figure(nrows=1, ncols=1, figwidth=8.75, figheight=5.0)

# %% [markdown]
# ## Surface Heat Fluxes

# %%
colors = ["m", "c", "y", "k"]
labels = ["parallel", "atmosphere-first", "ocean-first", "converged SWR"]
linestyles = ["--", ":", "-.", "-"]

fig, axs = pplt.subplots(
    nrows=2, ncols=2, height="45em", width="65em", sharey=2, spany=False
)

ims = []
ax = axs[0, 0]
for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece3[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    im = ax.plot(
        oifs_diagvar.sfc_sen_flx,
        color=color,
        label=label,
        ls=linestyle,
    )
    ims.append(im)
ax.format(
    ylabel=r"Heat Flux $[W \; m^{-2}]$",
    title="Surface Sensible Heat Flux",
    xlabel="Time",
)

ax = axs[0, 1]
for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece3[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    ax.plot(
        oifs_diagvar.sfc_lat_flx,
        color=color,
        label=label,
        ls=linestyle,
    )
ax.format(
    ylabel=r"Heat Flux $[W \; m^{-2}]$", title="Surface Latent Heat Flux", xlabel="Time"
)

ax = axs[1, 0]
for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece3[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    ax.plot(
        oifs_diagvar.sfc_swrad,
        color=color,
        label=label,
        ls=linestyle,
    )
ax.format(
    ylabel=r"Radiation $[W \; m^{-2}]$",
    title="Net Surface Shortwave Radiation",
    xlabel="Time",
)

ax = axs[1, 1]
for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece3[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    ax.plot(
        oifs_diagvar.sfc_lwrad,
        color=color,
        label=label,
        ls=linestyle,
    )
ax.format(
    ylabel=r"Radiation $[W \; m^{-2}]$",
    title="Net Surface Longwave Radiation",
    xlabel="Time",
)

axs.format(abc="a)", xrotation=30)
fig.legend(ims, frame=False, ncols=4, loc="b")

fig.savefig(plotting_output_dir / "ece3_surface_heat_fluxes.pdf")
# Out:
# Figure(nrows=2, ncols=2, figwidth=8.12, figheight=5.62)

# %%
colors = ["m", "c", "y", "k"]
labels = ["parallel", "atmosphere-first", "ocean-first", "converged SWR"]
linestyles = ["--", ":", "-.", "-"]

fig, axs = pplt.subplots(
    nrows=2, ncols=2, height="45em", width="65em", sharey=2, spany=False
)

ims = []
ax = axs[0, 0]
for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece4[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    im = ax.plot(
        oifs_diagvar.sfc_sen_flx,
        color=color,
        label=label,
        ls=linestyle,
    )
    ims.append(im)
ax.format(
    ylabel=r"Heat Flux $[W \; m^{-2}]$",
    title="Surface Sensible Heat Flux",
    xlabel="Time",
)

ax = axs[0, 1]
for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece4[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    ax.plot(
        oifs_diagvar.sfc_lat_flx,
        color=color,
        label=label,
        ls=linestyle,
    )
ax.format(
    ylabel=r"Heat Flux $[W \; m^{-2}]$", title="Surface Latent Heat Flux", xlabel="Time"
)

ax = axs[1, 0]
for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece4[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    ax.plot(
        oifs_diagvar.sfc_swrad,
        color=color,
        label=label,
        ls=linestyle,
    )
ax.format(
    ylabel=r"Radiation $[W \; m^{-2}]$",
    title="Net Surface Shortwave Radiation",
    xlabel="Time",
)

ax = axs[1, 1]
for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece4[i]
    color = colors[i]
    label = labels[i]
    linestyle = linestyles[i]
    ax.plot(
        oifs_diagvar.sfc_lwrad,
        color=color,
        label=label,
        ls=linestyle,
    )
ax.format(
    ylabel=r"Radiation $[W \; m^{-2}]$",
    title="Net Surface Longwave Radiation",
    xlabel="Time",
)

axs.format(abc="a)", xrotation=30)
fig.legend(ims, frame=False, ncols=4, loc="b")

fig.savefig(plotting_output_dir / "ece4_surface_heat_fluxes.pdf")
# Out:
# Figure(nrows=2, ncols=2, figwidth=8.12, figheight=5.62)

# %% [markdown]
# ## Cloud Cover

# %%
fig, ax = pplt.subplots(width="70em", height="30em")

for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece3[i]
    ax.plot(
        oifs_diagvar.total_cloud,
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(
    title="Total Cloud Cover (Control Experiment, ECE3)", xlabel="Time", ylabel="Cloud Cover", xrotation=30,
)
ax.legend(ncols=1)
fig.savefig(plotting_output_dir / "ece3_ccover.pdf")
# Out:
# Figure(nrows=1, ncols=1, figwidth=8.75, figheight=3.75)

# %%
fig, ax = pplt.subplots(width="70em", height="30em")

for i in range(len(colors)):
    oifs_diagvar = oifs_diagvar_ece4[i]
    ax.plot(
        oifs_diagvar.total_cloud,
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(
    title="Total Cloud Cover (Control Experiment, ECE4)", xlabel="Time", ylabel="Cloud Cover", xrotation=30,
)
ax.legend(ncols=1)
fig.savefig(plotting_output_dir / "ece4_ccover.pdf")
# Out:
# Figure(nrows=1, ncols=1, figwidth=8.75, figheight=3.75)

# %% [markdown]
# ## Vertical Temperature Profile

# %%
titles = [
    "Parallel",
    "Sequential Atmosphere-First",
    "Sequential Ocean-First",
    "Converged Schwarz Waveform Relaxation",
]

fig, axs = pplt.subplots(nrows=4, ncols=1, height="90em", width="70em")

for i in range(len(colors)):
    ax = axs[i]
    ax_title = titles[i]
    oifs_progvar = oifs_progvar_ece3[i]
    oifs_progvar = oifs_progvar.assign_coords(
        air_pressure=("nlev", oifs_progvar.pressure_f[0].data / 100)
    )
    oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
    im = ax.contourf(
        oifs_progvar.t[:, 50:] - 273.15,
        levels=14,
        transpose=True,
        discrete=True,
    )
    ax.format(xlabel="Time", ylabel="Air Pressure [hPa]", title=ax_title, xrotation=30)
    ax.invert_yaxis()
axs.format(
    suptitle="Vertical Atmospheric Temperature Profiles in BL (Control Experiment, ECE3)"
)
fig.colorbar(im, loc="b", title="Temperature [°C]")
fig.savefig(plotting_output_dir / "ece3_air_temperature_profile.pdf")
# Out:
# Figure(nrows=4, ncols=1, figwidth=8.75, figheight=11.25)

# %%
titles = [
    "Parallel",
    "Sequential Atmosphere-First",
    "Sequential Ocean-First",
    "Converged Schwarz Waveform Relaxation",
]

fig, axs = pplt.subplots(nrows=4, ncols=1, height="90em", width="70em")

for i in range(len(colors)):
    ax = axs[i]
    ax_title = titles[i]
    oifs_progvar = oifs_progvar_ece4[i]
    oifs_progvar = oifs_progvar.assign_coords(
        air_pressure=("nlev", oifs_progvar.pressure_f[0].data / 100)
    )
    oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
    im = ax.contourf(
        oifs_progvar.t[:, 50:] - 273.15,
        levels=14,
        transpose=True,
        discrete=True,
    )
    ax.format(xlabel="Time", ylabel="Air Pressure [hPa]", title=ax_title, xrotation=30)
    ax.invert_yaxis()
axs.format(
    suptitle="Vertical Atmospheric Temperature Profiles in BL (Control Experiment, ECE4)"
)
fig.colorbar(im, loc="b", title="Temperature [°C]")
fig.savefig(plotting_output_dir / "ece4_air_temperature_profile.pdf")
# Out:
# Figure(nrows=4, ncols=1, figwidth=8.75, figheight=11.25)

# %%
fig, axs = pplt.subplots(nrows=4, spany=False, height="45em", width="75em")

ax = axs[0]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece3[i]
    ax.plot(
        oifs_progvar.u.sel(nlev=60),
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(
    ylabel="Zonal Wind \n$[m\; s^{{-1}}]$",
    title="",
    xlabel="Time",
)

ax = axs[1]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece3[i]
    ax.plot(
        oifs_progvar.v.sel(nlev=60),
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(
    ylabel=f"Meridional Wind \n$[m\; s^{{-1}}]$",
    title="",
    xlabel="Time",
)

ax = axs[2]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece3[i]
    ax.plot(
        oifs_progvar.t.sel(nlev=60) - 273.15,
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(ylabel="Temperature \n$[°C]$", title="", xlabel="Time")

hs = []
ax = axs[3]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece3[i]
    h = ax.plot(
        oifs_progvar.q.sel(nlev=60) * 1e3,
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
    hs.append(h)
ax.format(
    ylabel="Humidity $[g\; kg^{{-1}}]$",
    title="",
    xlabel="Time",
    xrotation=30,
)

# axs.format(suptitle="OpenIFS Prognostic Variables on Lowest Model Level")

fig.legend(hs, ncols=4, frame=False, loc="b")
fig.savefig(plotting_output_dir / "ece3_progvars_oifs.pdf")
# Out:
# Figure(nrows=4, ncols=1, figwidth=9.38, figheight=5.62)

# %%
fig, axs = pplt.subplots(nrows=4, spany=False, height="45em", width="75em")

ax = axs[0]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece4[i]
    ax.plot(
        oifs_progvar.u.sel(nlev=60),
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(
    ylabel="Zonal Wind \n$[m\; s^{{-1}}]$",
    title="",
    xlabel="Time",
)

ax = axs[1]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece4[i]
    ax.plot(
        oifs_progvar.v.sel(nlev=60),
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(
    ylabel=f"Meridional Wind \n$[m\; s^{{-1}}]$",
    title="",
    xlabel="Time",
)

ax = axs[2]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece4[i]
    ax.plot(
        oifs_progvar.t.sel(nlev=60) - 273.15,
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(ylabel="Temperature \n$[°C]$", title="", xlabel="Time")

hs = []
ax = axs[3]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece4[i]
    h = ax.plot(
        oifs_progvar.q.sel(nlev=60) * 1e3,
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
    hs.append(h)
ax.format(
    ylabel="Humidity $[g\; kg^{{-1}}]$",
    title="",
    xlabel="Time",
    xrotation=30,
)

# axs.format(suptitle="OpenIFS Prognostic Variables on Lowest Model Level")

fig.legend(hs, ncols=4, frame=False, loc="b")
fig.savefig(plotting_output_dir / "ece4_progvars_oifs.pdf")
# Out:
# Figure(nrows=4, ncols=1, figwidth=9.38, figheight=5.62)

# %%
fig, axs = pplt.subplots(nrows=1, ncols=4, width="70em", height="30em")
axs.format(suptitle="Vertical Atmospheric Temperature Profiles (Control Experiment, ECE3)")
axs.format(abc="a)")
timestamps = [
    pd.Timestamp("2014-07-02 12:00"),
    pd.Timestamp("2014-07-03 00:00"),
    pd.Timestamp("2014-07-03 12:00"),
    pd.Timestamp("2014-07-04 12:00"),
]

ax = axs[0]
ims = []
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece3[i]
    oifs_progvar = oifs_progvar.assign_coords(
        air_pressure=("nlev", oifs_progvar.pressure_f[0].data / 100)
    )
    oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
    timestamp = timestamps[0]
    t_for_plotting = oifs_progvar.t.sel(time=timestamp)[45:] - 273.15
    im = ax.plot(
        t_for_plotting,
        t_for_plotting.air_pressure,
        label=labels[i],
        color=colors[i],
        ls=linestyles[i],
    )
    ims.append(im)
    ax.format(title=timestamp)

ax = axs[1]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece3[i]
    oifs_progvar = oifs_progvar.assign_coords(
        air_pressure=("nlev", oifs_progvar.pressure_f[0].data / 100)
    )
    oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
    timestamp = timestamps[1]
    t_for_plotting = oifs_progvar.t.sel(time=timestamp)[45:] - 273.15
    ax.plot(
        t_for_plotting,
        t_for_plotting.air_pressure,
        label=labels[i],
        color=colors[i],
        ls=linestyles[i],
    )
    ax.format(title=timestamp)

ax = axs[2]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece3[i]
    oifs_progvar = oifs_progvar.assign_coords(
        air_pressure=("nlev", oifs_progvar.pressure_f[0].data / 100)
    )
    oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
    timestamp = timestamps[2]
    t_for_plotting = oifs_progvar.t.sel(time=timestamp)[45:] - 273.15
    ax.plot(
        t_for_plotting,
        t_for_plotting.air_pressure,
        label=labels[i],
        color=colors[i],
        ls=linestyles[i],
    )
    ax.format(title=timestamp)

ax = axs[3]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece3[i]
    oifs_progvar = oifs_progvar.assign_coords(
        air_pressure=("nlev", oifs_progvar.pressure_f[0].data / 100)
    )
    oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
    timestamp = timestamps[3]
    t_for_plotting = oifs_progvar.t.sel(time=timestamp)[45:] - 273.15
    ax.plot(
        t_for_plotting,
        t_for_plotting.air_pressure,
        label=labels[i],
        color=colors[i],
        ls=linestyles[i],
    )
    ax.format(title=timestamp)


for ax in axs:
    ax.format(
        xlabel="Temperature [°C]",
        ylabel="Air Pressure [hPa]",
        yreverse=True,
        xlim=[-2, 12],
    )

fig.legend(ims, frame=False, ncols=4, loc="b")
fig.savefig(plotting_output_dir / "ece3_air_temperature_stratification.pdf")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File index.pyx:609, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1404302400000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/ece3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:577, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File index.pyx:611, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2014-07-02 12:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/ece3/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py:630, in DatetimeIndex.get_loc(self, key)
#     629 try:
# --> 630     return Index.get_loc(self, key)
#     631 except KeyError as err:
#
# File ~/mambaforge/envs/ece3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: Timestamp('2014-07-02 12:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/ece3/lib/python3.10/site-packages/xarray/core/indexes.py:789, in PandasIndex.sel(self, labels, method, tolerance)
#     788 try:
# --> 789     indexer = self.index.get_loc(label_value)
#     790 except KeyError as e:
#
# File ~/mambaforge/envs/ece3/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py:632, in DatetimeIndex.get_loc(self, key)
#     631 except KeyError as err:
# --> 632     raise KeyError(orig_key) from err
#
# KeyError: Timestamp('2014-07-02 12:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 20
#      18 oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
#      19 timestamp = timestamps[0]
# ---> 20 t_for_plotting = oifs_progvar.t.sel(time=timestamp)[45:] - 273.15
#      21 im = ax.plot(
#      22     t_for_plotting,
#      23     t_for_plotting.air_pressure,
#    (...)
#      26     ls=linestyles[i],
#      27 )
#      28 ims.append(im)
#
# File ~/mambaforge/envs/ece3/lib/python3.10/site-packages/xarray/core/dataarray.py:1662, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1546 def sel(
#    1547     self,
#    1548     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1552     **indexers_kwargs: Any,
#    1553 ) -> Self:
#    1554     """Return a new DataArray whose data is given by selecting index
#    1555     labels along the specified dimension(s).
#    1556
#    (...)
#    1660     Dimensions without coordinates: points
#    1661     """
# -> 1662     ds = self._to_temp_dataset().sel(
#    1663         indexers=indexers,
#    1664         drop=drop,
#    1665         method=method,
#    1666         tolerance=tolerance,
#    1667         **indexers_kwargs,
#    1668     )
#    1669     return self._from_temp_dataset(ds)
#
# File ~/mambaforge/envs/ece3/lib/python3.10/site-packages/xarray/core/dataset.py:3171, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    3103 """Returns a new dataset with each array indexed by tick labels
#    3104 along the specified dimension(s).
#    3105
#    (...)
#    3168
#    3169 """
#    3170 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 3171 query_results = map_index_queries(
#    3172     self, indexers=indexers, method=method, tolerance=tolerance
#    3173 )
#    3175 if drop:
#    3176     no_scalar_variables = {}
#
# File ~/mambaforge/envs/ece3/lib/python3.10/site-packages/xarray/core/indexing.py:193, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     191         results.append(IndexSelResult(labels))
#     192     else:
# --> 193         results.append(index.sel(labels, **options))
#     195 merged = merge_sel_results(results)
#     197 # drop dimension coordinates found in dimension indexers
#     198 # (also drop multi-index if any)
#     199 # (.sel() already ensures alignment)
#
# File ~/mambaforge/envs/ece3/lib/python3.10/site-packages/xarray/core/indexes.py:791, in PandasIndex.sel(self, labels, method, tolerance)
#     789                 indexer = self.index.get_loc(label_value)
#     790             except KeyError as e:
# --> 791                 raise KeyError(
#     792                     f"not all values found in index {coord_name!r}. "
#     793                     "Try setting the `method` keyword argument (example: method='nearest')."
#     794                 ) from e
#     796 elif label_array.dtype.kind == "b":
#     797     indexer = label_array
#
# KeyError: "not all values found in index 'time'. Try setting the `method` keyword argument (example: method='nearest')."
# Figure(nrows=1, ncols=4, figwidth=8.75, figheight=3.75)

# %%
fig, axs = pplt.subplots(nrows=1, ncols=4, width="70em", height="30em")
axs.format(suptitle="Vertical Atmospheric Temperature Profiles (Control Experiment, ECE4)")
axs.format(abc="a)")
timestamps = [
    pd.Timestamp("2014-07-02 12:00"),
    pd.Timestamp("2014-07-03 00:00"),
    pd.Timestamp("2014-07-03 12:00"),
    pd.Timestamp("2014-07-04 12:00"),
]

ax = axs[0]
ims = []
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece4[i]
    oifs_progvar = oifs_progvar.assign_coords(
        air_pressure=("nlev", oifs_progvar.pressure_f[0].data / 100)
    )
    oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
    timestamp = timestamps[0]
    t_for_plotting = oifs_progvar.t.sel(time=timestamp)[45:] - 273.15
    im = ax.plot(
        t_for_plotting,
        t_for_plotting.air_pressure,
        label=labels[i],
        color=colors[i],
        ls=linestyles[i],
    )
    ims.append(im)
    ax.format(title=timestamp)

ax = axs[1]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece4[i]
    oifs_progvar = oifs_progvar.assign_coords(
        air_pressure=("nlev", oifs_progvar.pressure_f[0].data / 100)
    )
    oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
    timestamp = timestamps[1]
    t_for_plotting = oifs_progvar.t.sel(time=timestamp)[45:] - 273.15
    ax.plot(
        t_for_plotting,
        t_for_plotting.air_pressure,
        label=labels[i],
        color=colors[i],
        ls=linestyles[i],
    )
    ax.format(title=timestamp)

ax = axs[2]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece4[i]
    oifs_progvar = oifs_progvar.assign_coords(
        air_pressure=("nlev", oifs_progvar.pressure_f[0].data / 100)
    )
    oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
    timestamp = timestamps[2]
    t_for_plotting = oifs_progvar.t.sel(time=timestamp)[45:] - 273.15
    ax.plot(
        t_for_plotting,
        t_for_plotting.air_pressure,
        label=labels[i],
        color=colors[i],
        ls=linestyles[i],
    )
    ax.format(title=timestamp)

ax = axs[3]
for i in range(len(colors)):
    oifs_progvar = oifs_progvar_ece4[i]
    oifs_progvar = oifs_progvar.assign_coords(
        air_pressure=("nlev", oifs_progvar.pressure_f[0].data / 100)
    )
    oifs_progvar = oifs_progvar.swap_dims({"nlev": "air_pressure"})
    timestamp = timestamps[3]
    t_for_plotting = oifs_progvar.t.sel(time=timestamp)[45:] - 273.15
    ax.plot(
        t_for_plotting,
        t_for_plotting.air_pressure,
        label=labels[i],
        color=colors[i],
        ls=linestyles[i],
    )
    ax.format(title=timestamp)


for ax in axs:
    ax.format(
        xlabel="Temperature [°C]",
        ylabel="Air Pressure [hPa]",
        yreverse=True,
        xlim=[-2, 18],
    )

fig.legend(ims, frame=False, ncols=4, loc="b")
fig.savefig(plotting_output_dir / "ece4_air_temperature_stratification.pdf")
# Out:
# Figure(nrows=1, ncols=4, figwidth=8.75, figheight=3.75)

# %%
# Level where difference of temperature is largest in panel c):
max_diff_level = (
    np.abs(
        oifs_progvar_ece3[2].t.sel(time=timestamp) - oifs_progvar_ece3[3].t.sel(time=timestamp)
    )
    .argmax()
    .load()
    .data[()]
)
print(max_diff_level)

#Which pressure value does this correspond to?
pressure_at_max_diff = (
    oifs_progvar_ece3[0].pressure_f.sel(nlev=max_diff_level + 1).mean().load().data[()]
)
print(pressure_at_max_diff)
# Out:
# 51
# 93046.38

# %% [markdown]
# ## NEMO Prognostic Variables

# %%
fig, axs = pplt.subplots(nrows=4, spany=False, height="45em", width="75em")

ax = axs[0]
for i in range(len(colors)):
    nemo_u = nemo_u_grids_ece3[i]
    ax.plot(
        nemo_u.vozocrtx.isel(depthu=0),
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(
    ylabel=f"Zonal Current \n $[m\; s^{{-1}}]$",
    title="",
    xlabel="Time",
)

ax = axs[1]
for i in range(len(colors)):
    nemo_v = nemo_v_grids_ece3[i]
    ax.plot(
        nemo_v.vomecrty.isel(depthv=0),
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(
    ylabel=f"Meridional Current \n $[m\; s^{{-1}}]$",
    title="",
    xlabel="Time",
)

ax = axs[2]
for i in range(len(colors)):
    nemo_t = nemo_t_grids_ece3[i]
    ax.plot(
        nemo_t.sosstsst,
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(ylabel=f"Temperature \n$[°C]$", title="", xlabel="Time")

hs = []
ax = axs[3]
for i in range(len(colors)):
    nemo_t = nemo_t_grids_ece3[i]
    h = ax.plot(
        nemo_t.vosaline.isel(deptht=0),
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
    hs.append(h)
ax.format(ylabel="Salinity [PSU]", title="", xlabel="Time")

axs.format(xrotation=30)
axs.format(suptitle="NEMO Prognostic Variables at the Surface (ECE3)")

fig.legend(hs, ncols=4, frame=False, loc="b")
fig.savefig(plotting_output_dir / "ece3_progvars_nemo.pdf")
# Out:
# Figure(nrows=4, ncols=1, figwidth=9.38, figheight=5.62)

# %%
fig, axs = pplt.subplots(nrows=4, spany=False, height="45em", width="75em")

ax = axs[0]
for i in range(len(colors)):
    nemo_u = nemo_u_grids_ece4[i]
    ax.plot(
        nemo_u.vozocrtx.isel(depthu=0),
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(
    ylabel=f"Zonal Current \n $[m\; s^{{-1}}]$",
    title="",
    xlabel="Time",
)

ax = axs[1]
for i in range(len(colors)):
    nemo_v = nemo_v_grids_ece4[i]
    ax.plot(
        nemo_v.vomecrty.isel(depthv=0),
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(
    ylabel=f"Meridional Current \n $[m\; s^{{-1}}]$",
    title="",
    xlabel="Time",
)

ax = axs[2]
for i in range(len(colors)):
    nemo_t = nemo_t_grids_ece4[i]
    ax.plot(
        nemo_t.sosstsst,
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
ax.format(ylabel=f"Temperature \n$[°C]$", title="", xlabel="Time")

hs = []
ax = axs[3]
for i in range(len(colors)):
    nemo_t = nemo_t_grids_ece4[i]
    h = ax.plot(
        nemo_t.vosaline.isel(deptht=0),
        color=colors[i],
        label=labels[i],
        alpha=alpha,
        ls=linestyles[i],
    )
    hs.append(h)
ax.format(ylabel="Salinity [PSU]", title="", xlabel="Time")

axs.format(xrotation=30)
axs.format(suptitle="NEMO Prognostic Variables at the Surface (ECE4)")

fig.legend(hs, ncols=4, frame=False, loc="b")
fig.savefig(plotting_output_dir / "ece4_progvars_nemo.pdf")
# Out:
# Figure(nrows=4, ncols=1, figwidth=9.38, figheight=5.62)
